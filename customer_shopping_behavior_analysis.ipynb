# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/customer_shopping_behavior.csv")

# %%
df.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   str
#  3   Item Purchased          3900 non-null   str
#  4   Category                3900 non-null   str
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   str
#  7   Size                    3900 non-null   str
#  8   Color                   3900 non-null   str
#  9   Season                  3900 non-null   str
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   str
#  12  Shipping Type           3900 non-null   str
#  13  Discount Applied        3900 non-null   str
#  14  Promo Code Used         3900 non-null   str
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.describe(include=object)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16680\3998025828.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include=object)
#        Gender Item Purchased  Category Location  Size  Color  Season  \
# count    3900           3900      3900     3900  3900   3900    3900
# unique      2             25         4       50     4     25       4
# top      Male         Blouse  Clothing  Montana     M  Olive  Spring
# freq     2652            171      1737       96  1755    177     999
#
# ...

# %%
mmissing_percentage=df.isnull().mean()*100
mmissing_percentage.sort_values(ascending=False)
# Out:
# Review Rating             0.948718
# Customer ID               0.000000
# Age                       0.000000
# Gender                    0.000000
# Category                  0.000000
# Item Purchased            0.000000
# Location                  0.000000
# Size                      0.000000
# Color                     0.000000
# Purchase Amount (USD)     0.000000
# Season                    0.000000
# Subscription Status       0.000000
# Shipping Type             0.000000
# Discount Applied          0.000000
# Promo Code Used           0.000000
# Previous Purchases        0.000000
# Payment Method            0.000000
# Frequency of Purchases    0.000000
# dtype: float64

# %%
df[["Review Rating"]].median()
# Out:
# Review Rating    3.8
# dtype: float64

# %%
df["Review Rating"]=df["Review Rating"].fillna(df["Review Rating"].median)

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.shape
# Out:
# (3900, 18)

# %%
df.dtypes
# Out:
# Customer ID                int64
# Age                        int64
# Gender                       str
# Item Purchased               str
# Category                     str
# Purchase Amount (USD)      int64
# Location                     str
# Size                         str
# Color                        str
# Season                       str
# Review Rating             object
# Subscription Status          str
# Shipping Type                str
# Discount Applied             str
# Promo Code Used              str
# Previous Purchases         int64
# Payment Method               str
# Frequency of Purchases       str
# dtype: object

# %%
df["Review Rating"].unique()
# Out:
# array([3.1, 3.5, 2.7, 2.9, 3.2, 2.6, 4.8, 4.1, 4.9, 4.5, 4.7, 2.8, 4.6,
#        3.3, 4.4, 3.6, 5.0, 4.0,
#        <bound method Series.median of 0       3.1
#        1       3.1
#        2       3.1
#        3       3.5
#        4       2.7
#               ...
#        3895    4.2
#        3896    4.5
#        3897    2.9
#        3898    3.8
#        3899    3.1
#        Name: Review Rating, Length: 3900, dtype: float64>, 4.2, 3.7, 3.9,
#        3.0, 3.8, 3.4, 4.3, 2.5], dtype=object)

# %%
df["Review Rating"] = pd.to_numeric(
    df["Review Rating"],
    errors="coerce"
)

# %%
df.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                        str
# Item Purchased                str
# Category                      str
# Purchase Amount (USD)       int64
# Location                      str
# Size                          str
# Color                         str
# Season                        str
# Review Rating             float64
# Subscription Status           str
# Shipping Type                 str
# Discount Applied              str
# Promo Code Used               str
# Previous Purchases          int64
# Payment Method                str
# Frequency of Purchases        str
# dtype: object

# %%
df.columns=df.columns.str.lower()

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['customer id', 'age', 'gender', 'item purchased', 'category',
#        'purchase amount (usd)', 'location', 'size', 'color', 'season',
#        'review rating', 'subscription status', 'shipping type',
#        'discount applied', 'promo code used', 'previous purchases',
#        'payment method', 'frequency of purchases'],
#       dtype='str')>

# %%
df.columns = df.columns.str.replace(" ", "_")

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')>

# %%
labels=["young-adult", "adult", "middle-age", "senior"]
df["age-group"]=pd.qcut(df["age"],q=4, labels=labels)

# %%
df[["age", "age-group"]]
# Out:
#       age    age-group
# 0      55   middle-age
# 1      19  young-adult
# 2      50   middle-age
# 3      21  young-adult
# 4      45   middle-age
# ...   ...          ...
# 3895   40        adult
# 3896   52   middle-age
# 3897   46   middle-age
# 3898   44        adult
# 3899   52   middle-age
#
# [3900 rows x 2 columns]

# %%
df["frequency_of_purchases"].value_counts()
# Out:
# frequency_of_purchases
# Every 3 Months    584
# Annually          572
# Quarterly         563
# Monthly           553
# Bi-Weekly         547
# Fortnightly       542
# Weekly            539
# Name: count, dtype: int64

# %%
frequency_days = {
    "Weekly": 7,
    "Bi-Weekly": 14,
    "Fortnightly": 14,
    "Monthly": 30,
    "Quarterly": 90,
    "Every 3 Months": 90,
    "Every 6 Months": 180,
    "Annually": 365
}

# %%
df["purchase_frequency_days"] = (
    df["frequency_of_purchases"]
    .map(frequency_days)
)

# %%
df["purchase_frequency_days"]
# Out:
# 0        14
# 1        14
# 2         7
# 3         7
# 4       365
#        ...
# 3895      7
# 3896     14
# 3897     90
# 3898      7
# 3899     90
# Name: purchase_frequency_days, Length: 3900, dtype: int64

# %%
df[
    [
        "frequency_of_purchases",
        "purchase_frequency_days"
    ]
].drop_duplicates().sort_values("purchase_frequency_days")
# Out:
#    frequency_of_purchases  purchase_frequency_days
# 2                  Weekly                        7
# 0             Fortnightly                       14
# 10              Bi-Weekly                       14
# 15                Monthly                       30
# 20         Every 3 Months                       90
# 6               Quarterly                       90
# 4                Annually                      365

# %%
df=df.drop("promo_code_used", axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age-group', 'purchase_frequency_days'],
#       dtype='str')
